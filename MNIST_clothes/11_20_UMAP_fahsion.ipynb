# %%
import numpy as np
import scipy.io.wavfile
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import os
from sklearn.preprocessing import normalize
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import scipy as sc

# %%
from tensorflow import keras
fashion_mnist = keras.datasets.fashion_mnist
(train_images, train_labels), (test_images,
                               test_labels) = fashion_mnist.load_data()

train_images = train_images.reshape(-1, 784)
test_images = test_images.reshape(-1, 784)

# %%
import pylab
def plot_color(matrix, labels, filename=""):
    x = matrix[:, 0].tolist()
    y = matrix[:, 1].tolist()
    plt.figure(figsize=(6, 6))
    pylab.scatter(x, y, c=labels, cmap='Dark2')
    if(len(filename) > 0): plt.savefig(filename)

# %%
def plot_with_labels(lowDWeights, labels, filename='tsne.png'):
    assert lowDWeights.shape[0] >= len(labels), "More labels than weights"
    label_c = np.array([i for i in range(10)])
    plt.figure(figsize=(10, 10))  # in inches
    for i, label in enumerate(labels):
        x, y = lowDWeights[i, :]
        plt.scatter(x, y, c=label_c)
        plt.annotate(label,
                     xy=(x, y),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom'
                     )

    plt.savefig(filename)

# %%
weights_e0 = np.load("layer1_epoch_0.npy")
weights_e1 = np.load("layer1_epoch_1.npy")
weights_e2 = np.load("layer1_epoch_2.npy")
weights_e3 = np.load("layer1_epoch_3.npy")
weights_e4 = np.load("layer1_epoch_4.npy")

# %% [markdown]
# # UMAP Projection: Layer 1

# %%
import umap

# %%
umap = umap.UMAP(n_neighbors=10, min_dist=0.01, metric='correlation')

# %%
embeddings = umap.fit_transform(weights_e0)
plot_color(embeddings, test_labels[:500])

# %%
embeddings = umap.fit_transform(weights_e1)
plot_color(embeddings, test_labels[:500])

# %%
embeddings = umap.fit_transform(weights_e2)
plot_color(embeddings, test_labels[:500])

# %%
embeddings = umap.fit_transform(weights_e3)
plot_color(embeddings, test_labels[:500])

# %%
embeddings = umap.fit_transform(weights_e4)
plot_color(embeddings, test_labels[:500])

# %% [markdown]
# # Projecting Layer 2

# %%
weights_e0 = np.load("layer2_epoch_0.npy")
weights_e1 = np.load("layer2_epoch_1.npy")
weights_e2 = np.load("layer2_epoch_2.npy")
weights_e3 = np.load("layer2_epoch_3.npy")
weights_e4 = np.load("layer2_epoch_4.npy")

# %%
embeddings = umap.fit_transform(weights_e0)
plot_color(embeddings, test_labels[:500])
# Out:
# /home/linneamay/anaconda3/envs/tensorflow/lib/python3.6/site-packages/umap/spectral.py:229: UserWarning: Embedding a total of 2 separate connected components using meta-embedding (experimental)
#   n_components

# %%
embeddings = umap.fit_transform(weights_e1)
plot_color(embeddings, test_labels[:500])
# Out:
# /home/linneamay/anaconda3/envs/tensorflow/lib/python3.6/site-packages/umap/spectral.py:229: UserWarning: Embedding a total of 2 separate connected components using meta-embedding (experimental)
#   n_components

# %%
embeddings = umap.fit_transform(weights_e2)
plot_color(embeddings, test_labels[:500])
# Out:
# /home/linneamay/anaconda3/envs/tensorflow/lib/python3.6/site-packages/umap/spectral.py:229: UserWarning: Embedding a total of 2 separate connected components using meta-embedding (experimental)
#   n_components

# %%
embeddings = umap.fit_transform(weights_e3)
plot_color(embeddings, test_labels[:500])
# Out:
# /home/linneamay/anaconda3/envs/tensorflow/lib/python3.6/site-packages/umap/spectral.py:229: UserWarning: Embedding a total of 3 separate connected components using meta-embedding (experimental)
#   n_components

# %%
embeddings = umap.fit_transform(weights_e4)
plot_color(embeddings, test_labels[:500])
# Out:
# /home/linneamay/anaconda3/envs/tensorflow/lib/python3.6/site-packages/umap/spectral.py:229: UserWarning: Embedding a total of 3 separate connected components using meta-embedding (experimental)
#   n_components
